# %%
import pandas as pd
import json
"""
     ██╗███████╗ ██████╗ ███╗   ██╗    ███████╗███╗   ██╗ ██████╗ ██████╗ ██████╗ ███████╗██████╗     
     ██║██╔════╝██╔═══██╗████╗  ██║    ██╔════╝████╗  ██║██╔════╝██╔═══██╗██╔══██╗██╔════╝██╔══██╗    
     ██║███████╗██║   ██║██╔██╗ ██║    █████╗  ██╔██╗ ██║██║     ██║   ██║██║  ██║█████╗  ██████╔╝    
██   ██║╚════██║██║   ██║██║╚██╗██║    ██╔══╝  ██║╚██╗██║██║     ██║   ██║██║  ██║██╔══╝  ██╔══██╗    
╚█████╔╝███████║╚██████╔╝██║ ╚████║    ███████╗██║ ╚████║╚██████╗╚██████╔╝██████╔╝███████╗██║  ██║    
 ╚════╝ ╚══════╝ ╚═════╝ ╚═╝  ╚═══╝    ╚══════╝╚═╝  ╚═══╝ ╚═════╝ ╚═════╝ ╚═════╝ ╚══════╝╚═╝  ╚═╝    
"""
# Read the Excel document
EX_PATH = r"Past-Simple.xlsx" #replace with file path
excel_data_df = pd.read_excel(EX_PATH, sheet_name='Sheet1')
# or read csv file
#excel_data_df = pd.read_csv(EX_PATH, sheet_name='Sheet1')

# %%
excel_data_df.columns.values[0] = 'id'
excel_data_df.columns.values[1] = 'sequence'
excel_data_df.columns.values[2] = 'raw_sentence'
excel_data_df.columns.values[3] = 'err_i'
excel_data_df.columns.values[4] = 'correct'
excel_data_df.columns.values[5] = 'err_code'

excel_data_df
# Out:
#     id  sequence                                       raw_sentence  err_i  \
# 0    1         1  I were so bored, so I decided to go to the par...      1
# 1    1         2   That sounds like fun! What do you do after that?      5
# 2    1         3  I hang out with them for a bit longer and then...      1
# 3    2         1  My sister spend hours studied for her exam. Sh...      2
# 4    2         2  That's impressive. Does she have a good chance...     -1
# 5    2         3  She's been prepared for months, so I think she...     -1
# 6    3         1  We gone to see the new Marvel movie on last Fr...      1
# 7    3         2  I've been wanting to see that. How are the spe...      7
# 8    3         3  The special effects was amazing! The visuals w...      3
# 9    4         1  I have a huge breakfast this morning, it is li...      8
# 10   4         2  Wow, that sounds delicious! Did you usually ea...      4
# 11   4         3  No, but my grandma made them for me so I could...     11
# 12   5         1  She was wrote me a really nice letter last wee...      1
# 13   5         2            That's sweet. Has she been busy lately?     -1
# 14   5         3  Yeah, she's been really busy with work and stuff.     -1
# 15   6         1  We went on a road trip with our family last we...     12
# 16   6         2  That sounds like a great trip! What are some o...      7
# 17   6         3  We seen some amazing scenery and went on a few...      1
# 18   7         1  I binge-watching that new show "Stranger Thing...      1
# 19   7         2                      No, I wasn't. Is it any good?      2
# 20   7         3  Yeah, it's really good! You should give it a try.     -1
# 21   8         1  My mom taken a photo of her birthday cake yest...      2
# 22   8         2         That's nice. Do you helped plan the party?      2
# 23   8         3     Yeah, I help plan it with my mom and siblings.      2
# 24   9         1  We visiting my grandparents in Florida last we...      1
# 25   9         2  That sounds like a relaxing vacation. Are you ...      6
# 26   9         3   Yeah, it were really nice to get away and relax.      2
# 27  10         1  We went to the beach last summer. The water wa...     20
# 28  10         2  That sounds like a lot of fun! Did you got sun...      9
# 29  10         3  Yes, I got a bit sunburned, but it were worth it.      8
# 30  11         1  I went to the park yesterday. The weather was ...     13
# 31  11         2         That sounds fun! Did you get tired easily?     -1
# 32  11         3  Yeah, I were getting a bit tired by the end, b...      2
# 33  12         1  My sister studies hard for her exam last week....     10
# 34  12         2                That's great! What was the subject?     -1
# 35  12         3    It were biology. She really loves that subject.      1
# 36  13         1  We went to the movies on Friday night. The mov...     18
# 37  13         2  I've been wanting to see that movie. How is th...      8
# 38  13         3  The plot was good, but there was some boring p...      6
# 39  14         1  My mom cooks dinner for us last night. She mad...      2
# 40  14         2  That sounds yummy! Does she make any dessert too?      3
# 41  14         3        Yes, she make a chocolate cake for dessert.      2
# 42  15         1  I visited my friend's house last weekend. We p...     14
# 43  15         2  That sounds like a great time! Have you beaten...     -1
# 44  15         3                            Not yet, but I'm close.     -1
#
#           correct  err_code
# 0             was         1
# 1             did         1
# 2            hung         2
# 3           spent         2
# 4               -         3
# 5               -         3
# 6            went         2
# 7             was         1
# 8            were         1
# 9             was         1
# 10             Do         1
# 11         resist         2
# 12              -         1
# 13              -         3
# 14              -         3
# 15          drove         2
# 16           were         1
# 17            saw         2
# 18  binge-watched         2
# 19        haven't         1
# 20              -         3
# 21           took         2
# 22            Did         1
# 23         helped         2
# 24        visited         2
# 25            Did         1
# 26            was         1
# 27          built         2
# 28            get         2
# 29            was         1
# 30         played         2
# 31              -         3
# 32            was         1
# 33       prepared         2
# 34              -         3
# 35            was         1
# 36           left         2
# 37            was         1
# 38           were         1
# 39         cooked         2
# 40            Did         1
# 41           made         2
# 42            had         2
# 43              -         3
# 44              -         3

# %%
excel_data_df['sentence'] = ''

for i, sentence in enumerate(excel_data_df['raw_sentence']):
    print(sentence)
    sentence = sentence.replace('\"', '\'')
    sub_sentence = sentence.split(" ")
    print(sub_sentence)
    #for word in sub_sentence:
    #    print('"' + word + '" ', end='')
    #print('\n')
    print (i)
    excel_data_df['sentence'][i] = sub_sentence
# Out:
# I were so bored, so I decided to go to the park yesterday. I played soccer with my friends and we even got a game going.
# ['I', 'were', 'so', 'bored,', 'so', 'I', 'decided', 'to', 'go', 'to', 'the', 'park', 'yesterday.', 'I', 'played', 'soccer', 'with', 'my', 'friends', 'and', 'we', 'even', 'got', 'a', 'game', 'going.']
# 0
# That sounds like fun! What do you do after that?
# ['That', 'sounds', 'like', 'fun!', 'What', 'do', 'you', 'do', 'after', 'that?']
# 1
# I hang out with them for a bit longer and then we all went our separate ways.
# ['I', 'hang', 'out', 'with', 'them', 'for', 'a', 'bit', 'longer', 'and', 'then', 'we', 'all', 'went', 'our', 'separate', 'ways.']
# 2
# My sister spend hours studied for her exam. She's trying to get into medical school, so she's been studying really hard.
# ['My', 'sister', 'spend', 'hours', 'studied', 'for', 'her', 'exam.', "She's", 'trying', 'to', 'get', 'into', 'medical', 'school,', 'so', "she's", 'been', 'studying', 'really', 'hard.']
# 3
# That's impressive. Does she have a good chance of getting in?
# ["That's", 'impressive.', 'Does', 'she', 'have', 'a', 'good', 'chance', 'of', 'getting', 'in?']
# 4
# She's been prepared for months, so I think she has a pretty good shot.
# ["She's", 'been', 'prepared', 'for', 'months,', 'so', 'I', 'think', 'she', 'has', 'a', 'pretty', 'good', 'shot.']
# 5
# We gone to see the new Marvel movie on last Friday. It was awesome, we loved it!
# ['We', 'gone', 'to', 'see', 'the', 'new', 'Marvel', 'movie', 'on', 'last', 'Friday.', 'It', 'was', 'awesome,', 'we', 'loved', 'it!']
# 6
# I've been wanting to see that. How are the special effects?
# ["I've", 'been', 'wanting', 'to', 'see', 'that.', 'How', 'are', 'the', 'special', 'effects?']
# 7
# The special effects was amazing! The visuals were incredible.
# ['The', 'special', 'effects', 'was', 'amazing!', 'The', 'visuals', 'were', 'incredible.']
# 8
# I have a huge breakfast this morning, it is literally the biggest plate of pancakes I've ever seen. It had butter and syrup on it.
# ['I', 'have', 'a', 'huge', 'breakfast', 'this', 'morning,', 'it', 'is', 'literally', 'the', 'biggest', 'plate', 'of', 'pancakes', "I've", 'ever', 'seen.', 'It', 'had', 'butter', 'and', 'syrup', 'on', 'it.']
# 9
# Wow, that sounds delicious! Did you usually eat that much breakfast?
# ['Wow,', 'that', 'sounds', 'delicious!', 'Did', 'you', 'usually', 'eat', 'that', 'much', 'breakfast?']
# 10
# No, but my grandma made them for me so I couldn't resisted.
# ['No,', 'but', 'my', 'grandma', 'made', 'them', 'for', 'me', 'so', 'I', "couldn't", 'resisted.']
# 11
# She was wrote me a really nice letter last week. She said she was thinking about me and missed me.
# ['She', 'was', 'wrote', 'me', 'a', 'really', 'nice', 'letter', 'last', 'week.', 'She', 'said', 'she', 'was', 'thinking', 'about', 'me', 'and', 'missed', 'me.']
# 12
# That's sweet. Has she been busy lately?
# ["That's", 'sweet.', 'Has', 'she', 'been', 'busy', 'lately?']
# 13
# Yeah, she's been really busy with work and stuff.
# ['Yeah,', "she's", 'been', 'really', 'busy', 'with', 'work', 'and', 'stuff.']
# 14
# We went on a road trip with our family last weekend. We drive all the way to Yellowstone National Park and back.
# ['We', 'went', 'on', 'a', 'road', 'trip', 'with', 'our', 'family', 'last', 'weekend.', 'We', 'drive', 'all', 'the', 'way', 'to', 'Yellowstone', 'National', 'Park', 'and', 'back.']
# 15
# That sounds like a great trip! What are some of the highlights?
# ['That', 'sounds', 'like', 'a', 'great', 'trip!', 'What', 'are', 'some', 'of', 'the', 'highlights?']
# 16
# We seen some amazing scenery and went on a few hikes.
# ['We', 'seen', 'some', 'amazing', 'scenery', 'and', 'went', 'on', 'a', 'few', 'hikes.']
# 17
# I binge-watching that new show "Stranger Things" last night. Have you seen it?
# ['I', 'binge-watching', 'that', 'new', 'show', "'Stranger", "Things'", 'last', 'night.', 'Have', 'you', 'seen', 'it?']
# 18
# No, I wasn't. Is it any good?
# ['No,', 'I', "wasn't.", 'Is', 'it', 'any', 'good?']
# 19
# Yeah, it's really good! You should give it a try.
# ['Yeah,', "it's", 'really', 'good!', 'You', 'should', 'give', 'it', 'a', 'try.']
# 20
# My mom taken a photo of her birthday cake yesterday.
# ['My', 'mom', 'taken', 'a', 'photo', 'of', 'her', 'birthday', 'cake', 'yesterday.']
# 21
# That's nice. Do you helped plan the party?
# ["That's", 'nice.', 'Do', 'you', 'helped', 'plan', 'the', 'party?']
# 22
# Yeah, I help plan it with my mom and siblings.
# ['Yeah,', 'I', 'help', 'plan', 'it', 'with', 'my', 'mom', 'and', 'siblings.']
# 23
# We visiting my grandparents in Florida last weekend. We went to the beach every day and even went on a boat tour.
# ['We', 'visiting', 'my', 'grandparents', 'in', 'Florida', 'last', 'weekend.', 'We', 'went', 'to', 'the', 'beach', 'every', 'day', 'and', 'even', 'went', 'on', 'a', 'boat', 'tour.']
# 24
# That sounds like a relaxing vacation. Are you enjoy yourself?
# ['That', 'sounds', 'like', 'a', 'relaxing', 'vacation.', 'Are', 'you', 'enjoy', 'yourself?']
# 25
# Yeah, it were really nice to get away and relax.
# ['Yeah,', 'it', 'were', 'really', 'nice', 'to', 'get', 'away', 'and', 'relax.']
# 26
# We went to the beach last summer. The water was cold, but we still had a lot of fun. We build sandcastles and played volleyball.
# ['We', 'went', 'to', 'the', 'beach', 'last', 'summer.', 'The', 'water', 'was', 'cold,', 'but', 'we', 'still', 'had', 'a', 'lot', 'of', 'fun.', 'We', 'build', 'sandcastles', 'and', 'played', 'volleyball.']
# 27
# That sounds like a lot of fun! Did you got sunburned?
# ['That', 'sounds', 'like', 'a', 'lot', 'of', 'fun!', 'Did', 'you', 'got', 'sunburned?']
# 28
# Yes, I got a bit sunburned, but it were worth it.
# ['Yes,', 'I', 'got', 'a', 'bit', 'sunburned,', 'but', 'it', 'were', 'worth', 'it.']
# 29
# I went to the park yesterday. The weather was nice and sunny. We playing soccer for a few hours.
# ['I', 'went', 'to', 'the', 'park', 'yesterday.', 'The', 'weather', 'was', 'nice', 'and', 'sunny.', 'We', 'playing', 'soccer', 'for', 'a', 'few', 'hours.']
# 30
# That sounds fun! Did you get tired easily?
# ['That', 'sounds', 'fun!', 'Did', 'you', 'get', 'tired', 'easily?']
# 31
# Yeah, I were getting a bit tired by the end, but it was worth it.
# ['Yeah,', 'I', 'were', 'getting', 'a', 'bit', 'tired', 'by', 'the', 'end,', 'but', 'it', 'was', 'worth', 'it.']
# 32
# My sister studies hard for her exam last week. She preparing for months and felt confident. She got an A on the exam.
# ['My', 'sister', 'studies', 'hard', 'for', 'her', 'exam', 'last', 'week.', 'She', 'preparing', 'for', 'months', 'and', 'felt', 'confident.', 'She', 'got', 'an', 'A', 'on', 'the', 'exam.']
# 33
# That's great! What was the subject?
# ["That's", 'great!', 'What', 'was', 'the', 'subject?']
# 34
# It were biology. She really loves that subject.
# ['It', 'were', 'biology.', 'She', 'really', 'loves', 'that', 'subject.']
# 35
# We went to the movies on Friday night. The movie was really good, but a bit long. We leave after two hours.
# ['We', 'went', 'to', 'the', 'movies', 'on', 'Friday', 'night.', 'The', 'movie', 'was', 'really', 'good,', 'but', 'a', 'bit', 'long.', 'We', 'leave', 'after', 'two', 'hours.']
# 36
# I've been wanting to see that movie. How is the plot?
# ["I've", 'been', 'wanting', 'to', 'see', 'that', 'movie.', 'How', 'is', 'the', 'plot?']
# 37
# The plot was good, but there was some boring parts.
# ['The', 'plot', 'was', 'good,', 'but', 'there', 'was', 'some', 'boring', 'parts.']
# 38
# My mom cooks dinner for us last night. She made my favorite dish, pasta with tomato sauce. It tasted delicious.
# ['My', 'mom', 'cooks', 'dinner', 'for', 'us', 'last', 'night.', 'She', 'made', 'my', 'favorite', 'dish,', 'pasta', 'with', 'tomato', 'sauce.', 'It', 'tasted', 'delicious.']
# 39
# That sounds yummy! Does she make any dessert too?
# ['That', 'sounds', 'yummy!', 'Does', 'she', 'make', 'any', 'dessert', 'too?']
# 40
# Yes, she make a chocolate cake for dessert.
# ['Yes,', 'she', 'make', 'a', 'chocolate', 'cake', 'for', 'dessert.']
# 41
# I visited my friend's house last weekend. We played video games for hours and have a lot of fun. His new game is really cool.
# ['I', 'visited', 'my', "friend's", 'house', 'last', 'weekend.', 'We', 'played', 'video', 'games', 'for', 'hours', 'and', 'have', 'a', 'lot', 'of', 'fun.', 'His', 'new', 'game', 'is', 'really', 'cool.']
# 42
# That sounds like a great time! Have you beaten the game yet?
# ['That', 'sounds', 'like', 'a', 'great', 'time!', 'Have', 'you', 'beaten', 'the', 'game', 'yet?']
# 43
# Not yet, but I'm close.
# ['Not', 'yet,', 'but', "I'm", 'close.']
# 44
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# ...
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   excel_data_df['sentence'][i] = sub_sentence
# C:\Users\asus\AppData\Local\Temp\ipykernel_26504\2809673568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel_data_df['sentence'][i] = sub_sentence

# %%
excel_data_df = excel_data_df.drop(columns='raw_sentence')

# %%
json_tense = """"conversation" : ["""
head = 0
tail = 1
indice = 0
for i,sequence in enumerate(excel_data_df['sequence']):
    indice = i
    if (sequence > tail or tail == 1):
        tail = sequence
    else:
        json_conv = excel_data_df[head:i]
        json_tense = json_tense + json_conv.to_json(orient='records') + ','

        head = i
        tail = sequence
        
json_conv = excel_data_df[head:indice]
json_tense = json_tense + json_conv.to_json(orient='records')

json_tense = "{" + json_tense.replace('\\', '') + "]}" 
json_tense
# Out:
# '{"conversation" : [[{"id":1,"sequence":1,"err_i":1,"correct":"was","err_code":1,"sentence":["I","were","so","bored,","so","I","decided","to","go","to","the","park","yesterday.","I","played","soccer","with","my","friends","and","we","even","got","a","game","going."]},{"id":1,"sequence":2,"err_i":5,"correct":"did","err_code":1,"sentence":["That","sounds","like","fun!","What","do","you","do","after","that?"]},{"id":1,"sequence":3,"err_i":1,"correct":"hung","err_code":2,"sentence":["I","hang","out","with","them","for","a","bit","longer","and","then","we","all","went","our","separate","ways."]}],[{"id":2,"sequence":1,"err_i":2,"correct":"spent","err_code":2,"sentence":["My","sister","spend","hours","studied","for","her","exam.","She\'s","trying","to","get","into","medical","school,","so","she\'s","been","studying","really","hard."]},{"id":2,"sequence":2,"err_i":-1,"correct":"-","err_code":3,"sentence":["That\'s","impressive.","Does","she","have","a","good","chance","of","getting","in?"]},{"id":2,"sequence":3,"err_i":-1,"correct":"-","err_code":3,"sentence":["She\'s","been","prepared","for","months,","so","I","think","she","has","a","pretty","good","shot."]}],[{"id":3,"sequence":1,"err_i":1,"correct":"went","err_code":2,"sentence":["We","gone","to","see","the","new","Marvel","movie","on","last","Friday.","It","was","awesome,","we","loved","it!"]},{"id":3,"sequence":2,"err_i":7,"correct":"was","err_code":1,"sentence":["I\'ve","been","wanting","to","see","that.","How","are","the","special","effects?"]},{"id":3,"sequence":3,"err_i":3,"correct":"were","err_code":1,"sentence":["The","special","effects","was","amazing!","The","visuals","were","incredible."]}],[{"id":4,"sequence":1,"err_i":8,"correct":"was","err_code":1,"sentence":["I","have","a","huge","breakfast","this","morning,","it","is","literally","the","biggest","plate","of","pancakes","I\'ve","ever","seen.","It","had","butter","and","syrup","on","it."]},{"id":4,"sequence":2,"err_i":4,"correct":"Do","err_code":1,"sentence":["Wow,","that","sounds","delicious!","Did","you","usually","eat","that","much","breakfast?"]},{"id":4,"sequence":3,"err_i":11,"correct":"resist","err_code":2,"sentence":["No,","but","my","grandma","made","them","for","me","so","I","couldn\'t","resisted."]}],[{"id":5,"sequence":1,"err_i":1,"correct":"-","err_code":1,"sentence":["She","was","wrote","me","a","really","nice","letter","last","week.","She","said","she","was","thinking","about","me","and","missed","me."]},{"id":5,"sequence":2,"err_i":-1,"correct":"-","err_code":3,"sentence":["That\'s","sweet.","Has","she","been","busy","lately?"]},{"id":5,"sequence":3,"err_i":-1,"correct":"-","err_code":3,"sentence":["Yeah,","she\'s","been","really","busy","with","work","and","stuff."]}],[{"id":6,"sequence":1,"err_i":12,"correct":"drove","err_code":2,"sentence":["We","went","on","a","road","trip","with","our","family","last","weekend.","We","drive","all","the","way","to","Yellowstone","National","Park","and","back."]},{"id":6,"sequence":2,"err_i":7,"correct":"were","err_code":1,"sentence":["That","sounds","like","a","great","trip!","What","are","some","of","the","highlights?"]},{"id":6,"sequence":3,"err_i":1,"correct":"saw","err_code":2,"sentence":["We","seen","some","amazing","scenery","and","went","on","a","few","hikes."]}],[{"id":7,"sequence":1,"err_i":1,"correct":"binge-watched","err_code":2,"sentence":["I","binge-watching","that","new","show","\'Stranger","Things\'","last","night.","Have","you","seen","it?"]},{"id":7,"sequence":2,"err_i":2,"correct":"haven\'t","err_code":1,"sentence":["No,","I","wasn\'t.","Is","it","any","good?"]},{"id":7,"sequence":3,"err_i":-1,"correct":"-","err_code":3,"sentence":["Yeah,","it\'s","really","good!","You","should","give","it","a","try."]}],[{"id":8,"sequence":1,"err_i":2,"correct":"took","err_code":2,"sentence":["My","mom","taken","a","photo","of","her","birthday","cake","yesterday."]},{"id":8,"sequence":2,"err_i":2,"correct":"Did","err_code":1,"sentence":["That\'s","nice.","Do"," ...

# %%
# Export file
# Write the JSON string to a file


with open(EX_PATH + '.json', 'w') as json_file:
    json.dump(json.loads(json_tense), json_file)

print('Data exported to data.json')
# Out:
# Data exported to data.json
